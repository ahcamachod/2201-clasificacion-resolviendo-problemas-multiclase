# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2201-clasificacion-resolviendo-problemas-multiclase/blob/aula-2/clasificacion_multiclase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/datos_estudiantes.csv')
df.head()
# Out:
#   Estado civil Migración          Sexo Edad en la matrícula Extranjero  \
# 0      Soltero        Sí  Masculinob20                   No         No
# 1      Soltero        Sí     Masculino                   19         No
# 2      Soltero        Sí     Masculino                   19         No
# 3      Soltero        Sí      Femenino                   20         No
# 4       Casado        No      Femenino                   45         No
#
#   Necesidades educativas especiales Moroso Pago de matrícula en día Becado  \
# 0                                No     Sí                       No   10.8
# 1                                No     No                       No     No
# 2                                No     No                       No     No
# 3                                No     No                       Sí     No
# 4                                No     No                       Sí     No
#
#    Tasa de desempleo  ...  disciplinas 1º semestre (aprobadas)  \
# ...

# %%
df.shape
# Out:
# (4424, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 28 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Estado civil                                4424 non-null   object
#  1   Migración                                   4424 non-null   object
#  2   Sexo                                        4424 non-null   object
#  3   Edad en la matrícula                        4424 non-null   object
#  4   Extranjero                                  4424 non-null   object
#  5   Necesidades educativas especiales           4424 non-null   object
#  6   Moroso                                      4424 non-null   object
#  7   Pago de matrícula en día                    4424 non-null   object
#  8   Becado                                      4424 non-null   object
#  9   Tasa de desempleo                           4424 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Estado civil', 'Migración', 'Sexo', 'Edad en la matrícula',
#        'Extranjero', 'Necesidades educativas especiales', 'Moroso',
#        'Pago de matrícula en día', 'Becado', 'Tasa de desempleo',
#        'Tasa de inflación', 'PIB', 'Curso', 'Período', 'Calificación previa',
#        'disciplinas 1º semestre (creditadas)',
#        'disciplinas 1º semestre (matriculadas)',
#        'disciplinas 1º semestre (evaluaciones)',
#        'disciplinas 1º semestre (aprobadas)',
#        'disciplinas 1º semestre (notas)',
#        'disciplinas 1º semestre (sin evaluaciones)',
#        'disciplinas 2º semestre (creditadas)',
#        'disciplinas 2º semestre (matriculadas)',
#        'disciplinas 2º semestre (evaluaciones)',
#        'disciplinas 2º semestre (aprobadas)',
#        'disciplinas 2º semestre (notas)',
#        'disciplinas 2º semestre (sin evaluaciones)', 'Target'],
#       dtype='object')

# %%
df.Target.unique()
# Out:
# array([nan, 'Graduado', 'Desertor', 'Matriculado'], dtype=object)
